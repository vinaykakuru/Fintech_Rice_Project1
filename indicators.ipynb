# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
csv_path = Path("C:/Users/brent/OneDrive/Documents/indicators.csv")

# %%
indicator_csv = pd.read_csv(csv_path)

# %%
indicator_csv.head()
# Out:
#                    INDICATOR|CODE
# 0  Age of Inventory (Public)|AOIP
# 1          Buyer Seller Index|BSI
# 2    Days on Zillow (Public)|DOZP
# 3          Home Sales (NSA)|SALES
# 4         Home Sales (SA)|SASALES

# %%
new_var = indicator_csv['INDICATOR|CODE']
type(new_var)
# Out:
# pandas.core.series.Series

# %%
my_commit =new_var.str.split("|",expand=True)

# %%
my_commit
# Out:
#                                                      0         1
# 0                            Age of Inventory (Public)      AOIP
# 1                                   Buyer Seller Index       BSI
# 2                              Days on Zillow (Public)      DOZP
# 3                                     Home Sales (NSA)     SALES
# 4                                      Home Sales (SA)   SASALES
# 5         Home Sold As Foreclosure - Ratio - All Homes   HSAFRAL
# 6                           Inventory Measure (Public)       IMP
# 7                     Inventory Measure - SSA (Public)      IMSP
# 8                   Inventory Measure - Tiers (Public)      IMTP
# 9                   Listings Price Cuts (SA) All Homes    LPCSAL
# 10                Listings Price Cuts (SA) Bottom Tier    LPCSBT
# 11               Listings Price Cuts (SA) Condominiums    LPCSCO
# 12                Listings Price Cuts (SA) Middle Tier    LPCSMT
# ...
